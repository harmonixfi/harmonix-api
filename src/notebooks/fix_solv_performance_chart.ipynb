# %%
import sys
import os

# Determine the root directory (one level up from the notebook directory)
root_dir = os.path.abspath('..')

# Add the root directory to sys.path
sys.path.append(root_dir)

# %%
import pandas as pd
import logging
import uuid
from sqlmodel import Session, select
from core.db import engine
from models.vault_performance import VaultPerformance
from services import solv_service
from bg_tasks.utils import calculate_roi

logger = logging.getLogger(__name__)

def fix_solv_performance():
    """Fix and update vault performance data with correct APY calculations."""
    
    # Load historical performance data
    logger.info("Loading historical performance data...")
    df_performance = pd.read_csv(
        '../data/backup-performance-solv-1733715959243.csv',
        parse_dates=['datetime'],  # This will still attempt to parse dates
        dtype={'datetime': str}  # Read 'datetime' as string to avoid parsing issues
    )

    # Preprocess 'datetime' to standardize the format
    df_performance['datetime'] = df_performance['datetime'].str.replace(
        r'(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2})(\.\d+)?(\+\d{2})', 
        r'\1\3', 
        regex=True
    )
    
    # Convert 'datetime' to datetime format, handling both formats
    df_performance['datetime'] = pd.to_datetime(df_performance['datetime'], errors='coerce', utc=True)

    # Resample to daily frequency
    df_performance = df_performance.set_index('datetime')
    df_performance = df_performance.resample('D').last().reset_index()
    
    # Fetch NAV data
    logger.info("Fetching NAV data from Solv...")
    df_nav = solv_service.fetch_nav_data()
    if df_nav is None:
        logger.error("Failed to fetch NAV data")
        return
    
    # Calculate corrected APYs for each day
    logger.info("Calculating corrected APYs...")
    
    with Session(engine) as session:
        for idx, row in df_performance.iterrows():
            current_date = pd.Timestamp(row['datetime']).tz_convert('UTC')  # Ensure current_date is UTC aware
            
            # Calculate 1-month APY
            one_month_ago = current_date - pd.DateOffset(months=1)
            
            # Ensure navDate is timezone-aware
            df_nav['navDate'] = pd.to_datetime(df_nav['navDate'], utc=True)  # Convert navDate to UTC if not already

            recent_nav = df_nav[df_nav['navDate'] <= current_date].iloc[-1]['adjustedNav']
            month_ago_nav = df_nav[df_nav['navDate'] <= one_month_ago].iloc[-1]['adjustedNav']
            days = (current_date - one_month_ago).days
            apy_1m = calculate_roi(recent_nav, month_ago_nav, days) * 100
            
            # Calculate 1-week APY
            one_week_ago = current_date - pd.DateOffset(weeks=1)
            week_ago_nav = df_nav[df_nav['navDate'] <= one_week_ago].iloc[-1]['adjustedNav']
            days = (current_date - one_week_ago).days
            apy_1w = calculate_roi(recent_nav, week_ago_nav, days) * 100
            
            # Insert new record
            new_performance = VaultPerformance(
                datetime=row['datetime'],
                total_locked_value=row['total_locked_value'] if pd.notna(row['total_locked_value']) else 0.0,  # Default to 0.0 if NaT
                benchmark=row['benchmark'] if pd.notna(row['benchmark']) else 0,  # Default to empty string if NaT
                pct_benchmark=row['pct_benchmark'] if pd.notna(row['pct_benchmark']) else 0.0,  # Default to 0.0 if NaT
                apy_1m=apy_1m,
                apy_1w=apy_1w,
                apy_ytd=row['apy_ytd'] if pd.notna(row['apy_ytd']) else 0.0,  # Default to 0.0 if NaT
                vault_id='2f782919-aa2f-403c-815d-37270c804660',  # Default to None if NaT
                risk_factor=row['risk_factor'] if pd.notna(row['risk_factor']) else 0.0,  # Default to 0.0 if NaT
                all_time_high_per_share=row['all_time_high_per_share'] if pd.notna(row['all_time_high_per_share']) else 0.0,  # Default to 0.0 if NaT
                total_shares=row['total_shares'] if pd.notna(row['total_shares']) else 0.0,  # Default to 0.0 if NaT
                sortino_ratio=row['sortino_ratio'] if pd.notna(row['sortino_ratio']) else 0.0,  # Default to 0.0 if NaT
                downside_risk=row['downside_risk'] if pd.notna(row['downside_risk']) else 0.0,  # Default to 0.0 if NaT
                unique_depositors=row['unique_depositors'] if pd.notna(row['unique_depositors']) else 0,  # Default to 0 if NaT
                earned_fee=row['earned_fee'] if pd.notna(row['earned_fee']) else 0.0,  # Default to 0.0 if NaT
                fee_structure=row['fee_structure'] if pd.notna(row['fee_structure']) else '',  # Default to empty string if NaT
                projected_apy=row['projected_apy'] if pd.notna(row['projected_apy']) else 0.0,  # Default to 0.0 if NaT
                id=uuid.uuid4(),  # Generate new UUID for each record
            )
            session.add(new_performance)
            session.commit()
            logger.info(f"Inserted performance for {row['datetime']}: 1M={apy_1m:.2f}%, 1W={apy_1w:.2f}%")


logging.basicConfig(level=logging.INFO)
fix_solv_performance()
# Out:
# INFO:__main__:Loading historical performance data...
# INFO:__main__:Fetching NAV data from Solv...
# INFO:__main__:Calculating corrected APYs...
# INFO:__main__:Inserted performance for 2024-07-23 00:00:00+00:00: 1M=7.15%, 1W=25.55%
# INFO:__main__:Inserted performance for 2024-07-24 00:00:00+00:00: 1M=7.69%, 1W=29.85%
# INFO:__main__:Inserted performance for 2024-07-25 00:00:00+00:00: 1M=6.40%, 1W=29.85%
# INFO:__main__:Inserted performance for 2024-07-26 00:00:00+00:00: 1M=7.33%, 1W=13.04%
# INFO:__main__:Inserted performance for 2024-07-27 00:00:00+00:00: 1M=7.24%, 1W=13.04%
# INFO:__main__:Inserted performance for 2024-07-28 00:00:00+00:00: 1M=7.92%, 1W=10.57%
# INFO:__main__:Inserted performance for 2024-07-29 00:00:00+00:00: 1M=7.92%, 1W=10.57%
# INFO:__main__:Inserted performance for 2024-07-30 00:00:00+00:00: 1M=8.75%, 1W=14.84%
# INFO:__main__:Inserted performance for 2024-07-31 00:00:00+00:00: 1M=9.24%, 1W=14.63%
# INFO:__main__:Inserted performance for 2024-08-01 00:00:00+00:00: 1M=8.89%, 1W=14.63%
# INFO:__main__:Inserted performance for 2024-08-02 00:00:00+00:00: 1M=8.89%, 1W=10.45%
# INFO:__main__:Inserted performance for 2024-08-03 00:00:00+00:00: 1M=7.82%, 1W=10.45%
# INFO:__main__:Inserted performance for 2024-08-04 00:00:00+00:00: 1M=8.54%, 1W=7.22%
# INFO:__main__:Inserted performance for 2024-08-05 00:00:00+00:00: 1M=8.54%, 1W=7.22%
# INFO:__main__:Inserted performance for 2024-08-06 00:00:00+00:00: 1M=10.57%, 1W=3.23%
# INFO:__main__:Inserted performance for 2024-08-07 00:00:00+00:00: 1M=13.15%, 1W=10.73%
# INFO:__main__:Inserted performance for 2024-08-08 00:00:00+00:00: 1M=13.76%, 1W=10.73%
# INFO:__main__:Inserted performance for 2024-08-09 00:00:00+00:00: 1M=15.27%, 1W=17.36%
# INFO:__main__:Inserted performance for 2024-08-10 00:00:00+00:00: 1M=16.30%, 1W=17.36%
# INFO:__main__:Inserted performance for 2024-08-11 00:00:00+00:00: 1M=14.34%, 1W=17.36%
# INFO:__main__:Inserted performance for 2024-08-12 00:00:00+00:00: 1M=14.65%, 1W=18.76%
# INFO:__main__:Inserted performance for 2024-08-13 00:00:00+00:00: 1M=14.65%, 1W=18.76%
# INFO:__main__:Inserted performance for 2024-08-14 00:00:00+00:00: 1M=14.65%, 1W=7.25%
# INFO:__main__:Inserted performance for 2024-08-15 00:00:00+00:00: 1M=13.66%, 1W=6.98%
# INFO:__main__:Inserted performance for 2024-08-16 00:00:00+00:00: 1M=13.66%, 1W=0.94%
# INFO:__main__:Inserted performance for 2024-08-17 00:00:00+00:00: 1M=13.66%, 1W=0.94%
# INFO:__main__:Inserted performance for 2024-08-18 00:00:00+00:00: 1M=13.66%, 1W=0.94%
# INFO:__main__:Inserted performance for 2024-08-19 00:00:00+00:00: 1M=11.23%, 1W=8.05%
# INFO:__main__:Inserted performance for 2024-08-20 00:00:00+00:00: 1M=11.23%, 1W=8.05%
# INFO:__main__:Inserted performance for 2024-08-21 00:00:00+00:00: 1M=9.94%, 1W=8.05%
# INFO:__main__:Inserted performance for 2024-08-22 00:00:00+00:00: 1M=9.94%, 1W=8.32%
# INFO:__main__:Inserted performance for 2024-08-23 00:00:00+00:00: 1M=11.68%, 1W=16.16%
# INFO:__main__:Inserted performance for 2024-08-24 00:00:00+00:00: 1M=10.84%, 1W=16.16%
# INFO:__main__:Inserted performance for 2024-08-25 00:00:00+00:00: 1M=10.84%, 1W=16.16%
# INFO:__main__:Inserted performance for 2024-08-26 00:00:00+00:00: 1M=9.91%, 1W=7.23%
# INFO:__main__:Inserted performance for 2024-08-27 00:00:00+00:00: 1M=9.91%, 1W=7.23%
# INFO:__main__:Inserted performance for 2024-08-28 00:00:00+00:00: 1M=9.18%, 1W=7.23%
# INFO:__main__:Inserted performance for 2024-08-29 00:00:00+00:00: 1M=9.18%, 1W=7.23%
# INFO:__main__:Inserted performance for 2024-08-30 00:00:00+00:00: 1M=9.08%, 1W=3.43%
# INFO:__main__:Inserted performance for 2024-08-31 00:00:00+00:00: 1M=8.30%, 1W=3.43%
# INFO:__main__:Inserted performance for 2024-09-01 00:00:00+00:00: 1M=8.29%, 1W=3.42%
# INFO:__main__:Inserted performance for 2024-09-02 00:00:00+00:00: 1M=8.29%, 1W=3.42%
# INFO:__main__:Inserted performance for 2024-09-03 00:00:00+00:00: 1M=8.29%, 1W=3.42%
# INFO:__main__:Inserted performance for 2024-09-04 00:00:00+00:00: 1M=8.29%, 1W=3.42%
# INFO:__main__:Inserted performance for 2024-09-05 00:00:00+00:00: 1M=8.29%, 1W=3.42%
# INFO:__main__:Inserted performance for 2024-09-06 00:00:00+00:00: 1M=8.29%, 1W=-0.01%
# INFO:__main__:Inserted performance for 2024-09-07 00:00:00+00:00: 1M=5.83%, 1W=-0.01%
# INFO:__main__:Inserted performance for 2024-09-08 00:00:00+00:00: 1M=5.83%, 1W=0.00%
# INFO:__main__:Inserted performance for 2024-09-09 00:00:00+00:00: 1M=4.45%, 1W=0.00%
# INFO:__main__:Inserted performance for 2024-09-10 00:00:00+00:00: 1M=4.45%, 1W=0.00%
# INFO:__main__:Inserted performance for 2024-09-11 00:00:00+00:00: 1M=4.45%, 1W=0.00%
# INFO:__main__:Inserted performance for 2024-09-12 00:00:00+00:00: 1M=6.06%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-13 00:00:00+00:00: 1M=6.06%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-14 00:00:00+00:00: 1M=6.06%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-15 00:00:00+00:00: 1M=6.12%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-16 00:00:00+00:00: 1M=6.12%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-17 00:00:00+00:00: 1M=6.12%, 1W=8.31%
# INFO:__main__:Inserted performance for 2024-09-18 00:00:00+00:00: 1M=6.73%, 1W=11.08%
# INFO:__main__:Inserted performance for 2024-09-19 00:00:00+00:00: 1M=5.26%, 1W=4.47%
# INFO:__main__:Inserted performance for 2024-09-20 00:00:00+00:00: 1M=5.06%, 1W=3.61%
# INFO:__main__:Inserted performance for 2024-09-21 00:00:00+00:00: 1M=5.06%, 1W=3.61%
# INFO:__main__:Inserted performance for 2024-09-22 00:00:00+00:00: 1M=5.33%, 1W=4.78%
# INFO:__main__:Inserted performance for 2024-09-23 00:00:00+00:00: 1M=3.67%, 1W=4.71%
# INFO:__main__:Inserted performance for 2024-09-24 00:00:00+00:00: 1M=3.82%, 1W=5.41%
# INFO:__main__:Inserted performance for 2024-09-25 00:00:00+00:00: 1M=3.59%, 1W=1.76%
# INFO:__main__:Inserted performance for 2024-09-26 00:00:00+00:00: 1M=-6.19%, 1W=-35.62%
# INFO:__main__:Inserted performance for 2024-09-27 00:00:00+00:00: 1M=-5.74%, 1W=-33.69%
# INFO:__main__:Inserted performance for 2024-09-28 00:00:00+00:00: 1M=-5.43%, 1W=-32.70%
# INFO:__main__:Inserted performance for 2024-09-29 00:00:00+00:00: 1M=-5.43%, 1W=-33.45%
# INFO:__main__:Inserted performance for 2024-09-30 00:00:00+00:00: 1M=-5.73%, 1W=-32.10%
# INFO:__main__:Inserted performance for 2024-10-01 00:00:00+00:00: 1M=-5.92%, 1W=-32.56%
# INFO:__main__:Inserted performance for 2024-10-02 00:00:00+00:00: 1M=-5.92%, 1W=-31.88%
# INFO:__main__:Inserted performance for 2024-10-03 00:00:00+00:00: 1M=-5.92%, 1W=5.70%
# INFO:__main__:Inserted performance for 2024-10-04 00:00:00+00:00: 1M=-5.92%, 1W=3.47%
# INFO:__main__:Inserted performance for 2024-10-05 00:00:00+00:00: 1M=-5.92%, 1W=1.95%
# INFO:__main__:Inserted performance for 2024-10-06 00:00:00+00:00: 1M=-5.92%, 1W=1.95%
# INFO:__main__:Inserted performance for 2024-10-07 00:00:00+00:00: 1M=-5.92%, 1W=0.00%
# INFO:__main__:Inserted performance for 2024-10-08 00:00:00+00:00: 1M=-3.21%, 1W=12.94%
# INFO:__main__:Inserted performance for 2024-10-09 00:00:00+00:00: 1M=-2.62%, 1W=15.91%
# INFO:__main__:Inserted performance for 2024-10-10 00:00:00+00:00: 1M=-2.13%, 1W=18.43%
# INFO:__main__:Inserted performance for 2024-10-11 00:00:00+00:00: 1M=-1.95%, 1W=19.38%
# INFO:__main__:Inserted performance for 2024-10-12 00:00:00+00:00: 1M=-2.54%, 1W=25.95%
# INFO:__main__:Inserted performance for 2024-10-13 00:00:00+00:00: 1M=-2.21%, 1W=27.83%
# INFO:__main__:Inserted performance for 2024-10-14 00:00:00+00:00: 1M=-1.94%, 1W=29.35%
# INFO:__main__:Inserted performance for 2024-10-15 00:00:00+00:00: 1M=-1.49%, 1W=16.77%
# INFO:__main__:Inserted performance for 2024-10-16 00:00:00+00:00: 1M=-1.71%, 1W=12.69%
# INFO:__main__:Inserted performance for 2024-10-17 00:00:00+00:00: 1M=-1.32%, 1W=12.18%
# INFO:__main__:Inserted performance for 2024-10-18 00:00:00+00:00: 1M=-1.54%, 1W=13.07%
# INFO:__main__:Inserted performance for 2024-10-19 00:00:00+00:00: 1M=-1.75%, 1W=8.18%
# INFO:__main__:Inserted performance for 2024-10-20 00:00:00+00:00: 1M=-1.56%, 1W=6.60%
# INFO:__main__:Inserted performance for 2024-10-21 00:00:00+00:00: 1M=-1.09%, 1W=7.49%
# INFO:__main__:Inserted performance for 2024-10-22 00:00:00+00:00: 1M=-0.52%, 1W=9.28%
# INFO:__main__:Inserted performance for 2024-10-23 00:00:00+00:00: 1M=-0.35%, 1W=11.06%
# INFO:__main__:Inserted performance for 2024-10-24 00:00:00+00:00: 1M=-0.33%, 1W=10.01%
# INFO:__main__:Inserted performance for 2024-10-25 00:00:00+00:00: 1M=0.66%, 1W=11.85%
# INFO:__main__:Inserted performance for 2024-10-26 00:00:00+00:00: 1M=11.52%, 1W=10.81%
# INFO:__main__:Inserted performance for 2024-10-27 00:00:00+00:00: 1M=10.97%, 1W=10.81%
# INFO:__main__:Inserted performance for 2024-10-28 00:00:00+00:00: 1M=12.34%, 1W=16.15%
# INFO:__main__:Inserted performance for 2024-10-29 00:00:00+00:00: 1M=12.49%, 1W=12.71%
# INFO:__main__:Inserted performance for 2024-10-30 00:00:00+00:00: 1M=11.76%, 1W=11.01%
# INFO:__main__:Inserted performance for 2024-10-31 00:00:00+00:00: 1M=11.73%, 1W=11.80%
# INFO:__main__:Inserted performance for 2024-11-01 00:00:00+00:00: 1M=10.96%, 1W=4.97%
# INFO:__main__:Inserted performance for 2024-11-02 00:00:00+00:00: 1M=10.96%, 1W=4.97%
# INFO:__main__:Inserted performance for 2024-11-03 00:00:00+00:00: 1M=10.96%, 1W=4.97%
# INFO:__main__:Inserted performance for 2024-11-04 00:00:00+00:00: 1M=11.86%, 1W=1.71%
# INFO:__main__:Inserted performance for 2024-11-05 00:00:00+00:00: 1M=12.80%, 1W=4.95%
# INFO:__main__:Inserted performance for 2024-11-06 00:00:00+00:00: 1M=13.57%, 1W=9.10%
# INFO:__main__:Inserted performance for 2024-11-07 00:00:00+00:00: 1M=13.55%, 1W=7.43%
# INFO:__main__:Inserted performance for 2024-11-08 00:00:00+00:00: 1M=11.32%, 1W=14.55%
# INFO:__main__:Inserted performance for 2024-11-09 00:00:00+00:00: 1M=10.66%, 1W=14.55%
# INFO:__main__:Inserted performance for 2024-11-10 00:00:00+00:00: 1M=10.13%, 1W=14.55%
# INFO:__main__:Inserted performance for 2024-11-11 00:00:00+00:00: 1M=10.57%, 1W=13.41%
# INFO:__main__:Inserted performance for 2024-11-12 00:00:00+00:00: 1M=10.64%, 1W=15.62%
# INFO:__main__:Inserted performance for 2024-11-13 00:00:00+00:00: 1M=11.18%, 1W=16.33%
# INFO:__main__:Inserted performance for 2024-11-14 00:00:00+00:00: 1M=11.40%, 1W=18.83%
# INFO:__main__:Inserted performance for 2024-11-15 00:00:00+00:00: 1M=12.44%, 1W=22.10%
# INFO:__main__:Inserted performance for 2024-11-16 00:00:00+00:00: 1M=12.69%, 1W=22.10%
# INFO:__main__:Inserted performance for 2024-11-17 00:00:00+00:00: 1M=12.25%, 1W=22.10%
# INFO:__main__:Inserted performance for 2024-11-18 00:00:00+00:00: 1M=12.05%, 1W=19.94%
# INFO:__main__:Inserted performance for 2024-11-19 00:00:00+00:00: 1M=11.77%, 1W=13.15%
# INFO:__main__:Inserted performance for 2024-11-20 00:00:00+00:00: 1M=11.77%, 1W=9.11%
# INFO:__main__:Inserted performance for 2024-11-21 00:00:00+00:00: 1M=11.26%, 1W=6.91%
# INFO:__main__:Inserted performance for 2024-11-22 00:00:00+00:00: 1M=10.36%, 1W=0.61%
# INFO:__main__:Inserted performance for 2024-11-23 00:00:00+00:00: 1M=10.20%, 1W=0.61%
# INFO:__main__:Inserted performance for 2024-11-24 00:00:00+00:00: 1M=10.01%, 1W=0.61%
# INFO:__main__:Inserted performance for 2024-11-25 00:00:00+00:00: 1M=12.32%, 1W=13.04%
# INFO:__main__:Inserted performance for 2024-11-26 00:00:00+00:00: 1M=14.34%, 1W=22.53%
# INFO:__main__:Inserted performance for 2024-11-27 00:00:00+00:00: 1M=15.28%, 1W=27.08%
# INFO:__main__:Inserted performance for 2024-11-28 00:00:00+00:00: 1M=13.47%, 1W=26.73%
# INFO:__main__:Inserted performance for 2024-11-29 00:00:00+00:00: 1M=13.61%, 1W=28.17%
# INFO:__main__:Inserted performance for 2024-11-30 00:00:00+00:00: 1M=13.83%, 1W=28.17%
# INFO:__main__:Inserted performance for 2024-12-01 00:00:00+00:00: 1M=14.75%, 1W=28.17%
# INFO:__main__:Inserted performance for 2024-12-02 00:00:00+00:00: 1M=14.35%, 1W=11.51%
# INFO:__main__:Inserted performance for 2024-12-03 00:00:00+00:00: 1M=16.47%, 1W=11.49%
# INFO:__main__:Inserted performance for 2024-12-04 00:00:00+00:00: 1M=15.40%, 1W=7.08%
# INFO:__main__:Inserted performance for 2024-12-05 00:00:00+00:00: 1M=12.96%, 1W=1.68%
# INFO:__main__:Inserted performance for 2024-12-06 00:00:00+00:00: 1M=14.25%, 1W=8.81%
# INFO:__main__:Inserted performance for 2024-12-07 00:00:00+00:00: 1M=14.28%, 1W=8.81%
# INFO:__main__:Inserted performance for 2024-12-08 00:00:00+00:00: 1M=13.38%, 1W=8.81%
# INFO:__main__:Inserted performance for 2024-12-09 00:00:00+00:00: 1M=13.38%, 1W=10.44%
